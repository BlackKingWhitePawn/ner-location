# %%
from deeppavlov import train_model
from deeppavlov.core.commands.utils import parse_config

model_config = parse_config('ner_collection3_bert')

# dataset that the model was trained on
print(model_config['dataset_reader']['data_path'])
# Out:
# ~/.deeppavlov/downloads/collection3/

# %%
# !python -m deeppavlov install ner_collection3_bert
# Out:
# ...
# Ignoring transformers: markers 'python_version < "3.8"' don't match your environment
# ...
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.
# WARNING: There was an error checking the latest version of pip.

# %%
model_config['dataset_reader']['data_path'] = 'data/train2.txt'

# %%
ner_model = train_model(model_config)
# Out:
# 2024-05-13 13:06:01.191 INFO in 'deeppavlov.core.data.utils'['utils'] at line 97: Downloading from http://files.deeppavlov.ai/deeppavlov_data/collection3_anh.tar.gz to C:\ONLY_ASCII\New folder (37)\Studing\studing\nlp-24\ner-location\data\train2.txt\collection3_anh.tar.gz
# 100%|██████████| 964k/964k [00:02<00:00, 359kB/s]
# 2024-05-13 13:06:04.851 INFO in 'deeppavlov.core.data.utils'['utils'] at line 284: Extracting C:\ONLY_ASCII\New folder (37)\Studing\studing\nlp-24\ner-location\data\train2.txt\collection3_anh.tar.gz archive into C:\ONLY_ASCII\New folder (37)\Studing\studing\nlp-24\ner-location\data\train2.txt
# 2024-05-13 13:06:05.221 WARNING in 'deeppavlov.core.trainers.fit_trainer'['fit_trainer'] at line 66: TorchTrainer got additional init parameters ['pytest_max_batches', 'pytest_batch_size'] that will be ignored:
# ...

# %%
ner_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ner_model
#
# NameError: name 'ner_model' is not defined
